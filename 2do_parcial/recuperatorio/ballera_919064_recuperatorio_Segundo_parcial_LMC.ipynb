# %% [markdown]
# Laboratorio de Métodos Cuantitativos para la gestión
#
# ---
# ## Recuperatorio del Segundo Parcial

# %% [markdown]
# ---
#
# Nombre y Apellido: Alexander Ballera

# %% [markdown]
# ---
# Número de registro: 919064

# %% [markdown]
# ---
# ### Importo Librerías necesarias

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy_financial as nf

# %% [markdown]
# ### Funciones y variables que utilizaré en el desarrollo del parcial

# %%
# Valor máximo de los ejes de coordenadas para mejor visualización
def x_y_max (value, factor, eje):
    value = int(float(value))
    return value*factor if (eje == 'x') else (value + factor)

# %%
# Fórmula de Equivalencia
def tasa_equivalente(i_t1, t2, t1):
    return (1 + i_t1) ** (t2 / t1) - 1

# %%
# Período de recuperación descontado
def payback_desc(flujos, rate):
    acum_desc = 0
    prd = None
    inversion_inicial = abs(flujos[0])
    
    for t in range(1, len(flujos)):
        # Descontar el flujo de caja actual
        discounted_flow = flujos[t] / (1 + rate)**t
        acum_desc += discounted_flow

        # Verificar si el flujo de caja descontado acumulado es mayor o igual a la inversión inicial
        if acum_desc >= inversion_inicial:
            # Si es así, calcular el período de recuperación descontado
            remaining_investment = inversion_inicial - (acum_desc - discounted_flow)
            prd = t - 1 + (remaining_investment / discounted_flow)
            break
    
    return prd

# %%
# Variables
layout = 'constrained'
figsize = (12,6)

# %% [markdown]
# ---
#
# # Ejercicio 1
#
# ---
#
# Supongamos que una empresa tiene las siguientes funciones:
#
# - Función de Ingreso Marginal (IMg): $$ IMg(q) = 120 - 0.04 \cdot q $$
#
#   donde $q$ es la cantidad producida.
#
# - Función de Costo Marginal (CMg): $$ CMg(q) = 0.002 \cdot q^2 - 0.3 \cdot q + 70 $$
#
# Además, se sabe que el **costo fijo** de la empresa es de **$1500.**
#
# 1.  **Recuperar la función de Ingreso Total (I(q))**:  Asume que el ingreso total es cero cuando la cantidad producida es cero ($I(0) = 0$).
# 2.  **Recuperar la función de Costo Total (C(q))**
# 3.  **Calcular la función de Beneficio Total (B(q))**
# 4.  **Encontrar la cantidad óptima (q*)**: Determina la cantidad de producción que maximiza el beneficio. Puedes lograr esto igualando el ingreso marginal al costo marginal ($IMg(q) = CMg(q)$) y resolviendo para $q$. Considera solo valores de $q > 0$.
# 5.  **Calcular el Beneficio Máximo (B(q*))**
# 6.  **Visualizar las funciones**: Grafica las funciones de ingreso total, costo total y beneficio total en el mismo gráfico para visualizar el punto de beneficio máximo. Interpretar el gráfico.

# %% [markdown]
# ### 1.  **Recuperar la función de Ingreso Total (I(q))**:  Asume que el ingreso total es cero cuando la cantidad producida es cero ($I(0) = 0$).

# %%
# Paso 1: Defino variables simbólicas
q = sp.symbols('q', positive=True)
q
# Out:
# q

# %%
# Paso 2: Defino la función de Ingreso Marginal
IMg = 120.0 - 0.04*q
IMg
# Out:
# 120.0 - 0.04*q

# %%
# Paso 3: Integro para obtener la función de Ingreso Total con I(0) = 0
# como condición inicial, por lo que no agrego constante de integración (F)
I = sp.integrate(IMg, q)
I = sp.simplify(I)
I
# Out:
# q*(120.0 - 0.02*q)

# %%
# Derivo I(q) para validar que sea igual a IMg
sp.diff(I, q).simplify() == IMg  # Deben ser iguales
# Out:
# True

# %% [markdown]
# ### 2.  **Recuperar la función de Costo Total (C(q))**

# %%
# Paso 1: Defino las variables simbólicas: Costo Fijo F
F = sp.symbols('F')
F
# Out:
# F

# %%
# Paso 2: Defino la función de Ingreso Marginal
CMg = 0.002*q**2 - 0.3*q + 70.0
CMg = sp.simplify(CMg)
CMg
# Out:
# 0.002*q**2 - 0.3*q + 70.0

# %%
# Paso 3: Integro la función de Costo Marginal para obtener la función de Costo Total
C = sp.integrate(CMg, q) + F
C = sp.simplify(C)
C
# Out:
# F + 0.000666666666666667*q**3 - 0.15*q**2 + 70.0*q

# %%
# Paso 4: Sustituyo C0 = F = 1500.00 en la función de Costo Total
C = C.subs(F, 1500)
C
# Out:
# 0.000666666666666667*q**3 - 0.15*q**2 + 70.0*q + 1500

# %% [markdown]
# ### 3.  **Calcular la función de Beneficio Total (B(q))**

# %%
B = I - C
B = sp.simplify(B)
B
# Out:
# -0.000666666666666667*q**3 + 0.13*q**2 + 50.0*q - 1500.0

# %% [markdown]
# ### 4.  **Encontrar la cantidad óptima (q*)**: Determina la cantidad de producción que maximiza el beneficio. Puedes lograr esto igualando el ingreso marginal al costo marginal ($IMg(q) = CMg(q)$) y resolviendo para $q$. Considera solo valores de $q > 0$.

# %%
q_opt = round(sp.solve(sp.Eq(IMg, CMg), q)[0])
q_opt.evalf()
# Out:
# 236.000000000000

# %% [markdown]
# ### 5.  **Calcular el Beneficio Máximo (B(q*))**

# %%
B_opt = B.subs(q, q_opt)
round(B_opt.evalf(), 2)
# Out:
# 8777.64

# %% [markdown]
# ### 6.  **Visualizar las funciones**: Grafica las funciones de ingreso total, costo total y beneficio total en el mismo gráfico para visualizar el punto de beneficio máximo. Interpretar el gráfico.

# %%
# Paso 1: Defino vaiables necesarias
# Valor máximo en el eje x para mejor visualización
x_max = int(float(q_opt))
x_max = x_y_max (x_max, 1.75, 'x')

# Valor máximo en el eje y para mejor visualización
y_max = 45000

# Creo un rango de cantidades producidas
q_grid = np.linspace(0, x_max, 500)

# %%
# Paso 2: Convierto las funciones simbólicas a funciones numéricas
I_num = sp.lambdify(q, I, modules=['numpy'])
C_num = sp.lambdify(q, C, modules=['numpy'])
B_num = sp.lambdify(q, B, modules=['numpy'])

# %%
# Paso 3: Evalúo las funciones en el rango de cantidades
I_vals = I_num(q_grid)
C_vals = C_num(q_grid)
B_vals = B_num(q_grid)

# %%
# Paso 4: Establezco dominio de x y variables

# Variables
I_opt = float(I_num(q_opt))
C_opt = float(C_num(q_opt))
B_opt = float(B_num(q_opt))
q_opt = float(q_opt)
print(f'I_opt: {I_opt:.2f}')
print(f'C_opt: {C_opt:.2f}')
print(f'B_opt: {B_opt:.2f}')
print(f'q_opt: {q_opt}')
# Out:
# I_opt: 27206.08
# C_opt: 18428.44
# B_opt: 8777.64
# q_opt: 236.0

# %%
# Paso 4: Creo el gráfico
fig, axs = plt.subplots(figsize=(12, 6))


# Grafico las funciones
axs.plot(q_grid, I_vals, label='Ingreso Total (I)', color='blue')
axs.plot(q_grid, C_vals, label='Costo Total (C)', color='red')
axs.plot(q_grid, B_vals, label='Beneficio (B)', color='green')

# Marco el punto óptimo
axs.scatter(q_opt, B_opt, color='purple', s=60, label=f'Óptimo: q*={q_opt:.2f}, B*={B_opt:.2f}', marker='*', zorder=5)
axs.scatter(q_opt, I_opt, color='blue', s=60, zorder=4, marker='o')
axs.scatter(q_opt, C_opt, color='red', s=60, zorder=4, marker='o')

# Líneas de referencias
axs.vlines(x=q_opt, ymin=axs.get_ylim()[0], ymax=B_opt, color='purple', linestyle='--', alpha=0.7)
axs.hlines(y=B_opt, xmin=axs.get_xlim()[0], xmax=q_opt, color='purple', linestyle='--', alpha=0.7)

# Flecha bidireccional mostrando la distancia máxima (beneficio)
axs.annotate('', 
            xy=(q_opt, I_opt), 
            xytext=(q_opt, C_opt),
            arrowprops=dict(arrowstyle='<->', color='green', lw=1.5))

# Etiqueta explicativa de la brecha
axs.text(q_opt + 6, (I_opt + C_opt) / 2.1, 
        f'Brecha máxima\nB* = {B_opt:.2f}', 
        fontsize=10, color='green', fontweight='bold',
        bbox=dict(boxstyle="round,pad=0.5", facecolor="lightgreen", alpha=0.7))

# Configuro Gráfico
axs.grid(True, which='both', linestyle='--', linewidth=0.5)
axs.set_title('Funciones de Ingreso Total, Costo Total y Beneficio Total')
axs.set_xlabel('Cantidad Producida (q)')
axs.set_ylabel('Valor Monetario')
axs.set_xlim(0, x_max)
axs.set_ylim(0, y_max)
axs.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación Económica del Gráfico:**
#
# **1. Zona de Beneficios Crecientes (q < 236 unidades):**
#
# Cuando la empresa produce menos de 236 unidades, el ingreso marginal supera al costo marginal (IMg > CMg). Esto significa que cada unidad adicional producida aporta más ingresos que costos, incrementando el beneficio total. En este rango, el incentivo económico de la empresa es **expandir la producción** hacia el punto óptimo.
#
# **2. Punto de Maximización del Beneficio (q* = 236 unidades):**
#
# En q* = 236 unidades se alcanza el **equilibrio de maximización** donde IMg = CMg. En este punto:
# - Ingreso Total: I(236) = $27,206.08
# - Costo Total: C(236) = $18,428.44
# - **Beneficio Máximo: B* = $8,777.64**
#
# Este es el nivel óptimo de producción que maximiza el beneficio económico de la empresa. Producir exactamente 236 unidades genera la mayor diferencia posible entre ingresos y costos.
#
# **3. Zona de Beneficios Decrecientes (q > 236 unidades):**
# Para cantidades superiores a 236 unidades, el costo marginal supera al ingreso marginal (CMg > IMg). Cada unidad adicional producida reduce el beneficio total, ya que los costos crecen más rápido que los ingresos. El incentivo económico en esta zona es **reducir la producción** hacia el punto óptimo.
#
# **4. Rango de Operación Viable:**
#
# El gráfico muestra que la empresa genera beneficios positivos (B(q) > 0) en el intervalo donde la curva de Ingreso Total está por encima de la curva de Costo Total. Los puntos de quiebre (donde B(q) = 0) marcan el **rango operacional mínimo** dentro del cual la empresa puede subsistir sin generar pérdidas. Operar fuera de este rango implica beneficios negativos (pérdidas).
#
# **Conclusión:**
#
# La empresa debe producir exactamente **236 unidades** para maximizar su beneficio en **$8,777.64**. Este análisis demuestra la importancia de igualar el ingreso marginal al costo marginal (condición de primer orden) para alcanzar la eficiencia económica en la producción.

# %% [markdown]
# ---
#
# # Ejercicio 2
#
# ---
#
# Las funciones de oferta y demanda de cierto producto están dadas por:
#
# $$O: p=20+3q$$
#
# $$D:p= 100-q^2$$
#
#
# 1-Determinar el excedente del consumidor y del productor
#
# 2-Graficar ambas funciones en un mismo gráfico, donde el eje vertical debe ser el precio y el horizontal la cantidad.
#
# 3-Sombrear las áreas correspondientes a los excedentes encontrados indicando en el gráfico cuál es el excedente del consumidor y cuál el del productor e interpretar

# %% [markdown]
# ### 1. Determinar el excedente del consumidor y del productor

# %%
# Planteo y validación
# Las funciones de oferta y demanda ya se encuentran planteadas como funciones inversas
# de precio en función de cantidad. Por lo tanto, no es necesario realizar modificaciones
# adicionales como funciones inversas.

# %%
# Paso 1 Defino las variables simbólicas
p, q = sp.symbols('p q', real=True, positive=True)
p, q
# Out:
# (p, q)

# %%
# Paso 2 Defino la función de oferta 
P_s = 20.0 + 3.0*q
P_s
# Out:
# 3.0*q + 20.0

# %%
# Paso 3 Defino la función de demanda
P_d = 100.0 - q**2
P_d
# Out:
# 100.0 - q**2

# %%
# Paso 4 Encuentro cantidad óptima q* de equilibrio de mercado P_s(q) = P_d(q)
q_eq = sp.Eq(P_d, P_s)
q_eq = sp.solve(q_eq, q)
q_eq = round(q_eq[0], 2)
q_eq
# Out:
# 7.57

# %%
# Paso 5 Encuentro precio de equilibrio
p_eq = P_s.subs(q, q_eq)
p_eq = round(p_eq, 2)
p_eq
# Out:
# 42.71

# %%
print("EQUILIBRIO DEL MERCADO:")
print(f"  Ecuación: {P_d} = {P_s}")
print(f"  q* = {q_eq}")
print(f"  p* = {p_eq:.2f}")
# Out:
# EQUILIBRIO DEL MERCADO:
#   Ecuación: 100.0 - q**2 = 3.0*q + 20.0
#   q* = 7.57
#   p* = 42.71

# %%
# Paso 6 Excedente del Consumidor y del Productor
# Calculo con antiderivada y barrow para hallar EC y EP

print("INTERPRETACIÓN:")
print("  • EC mide el área entre la curva de demanda y el precio de equilibrio")
print("  • EP mide el área entre el precio de equilibrio y la curva de oferta")
print()
print("OBJETIVOS:")
print(f"  • EC = ∫[0, {q_eq}] [P_d(q) - {p_eq:.2f}] dq")
print(f"  • EP = ∫[0, {q_eq}] [{p_eq:.2f} - P_s(q)] dq")
# Out:
# INTERPRETACIÓN:
#   • EC mide el área entre la curva de demanda y el precio de equilibrio
#   • EP mide el área entre el precio de equilibrio y la curva de oferta
#
# OBJETIVOS:
#   • EC = ∫[0, 7.57] [P_d(q) - 42.71] dq
#   • EP = ∫[0, 7.57] [42.71 - P_s(q)] dq

# %%
# Paso 7 Excedente del Consumidor (EC)
EC = sp.integrate(P_d - p_eq, (q, 0, q_eq))

print('''
EC: Es el beneficio que obtienen los consumidores por pagar un precio menor
al que estaban dispuestos a pagar.
''')
print(f"EC = {EC:.2f}")
# Out:
# EC: Es el beneficio que obtienen los consumidores por pagar un precio menor
# al que estaban dispuestos a pagar.
#
# EC = 289.08

# %%
# Paso 8 Excedente del Productor (EP)
EP = sp.integrate(p_eq - P_s, (q,0, q_eq))

print('''
EP: Es el beneficio que obtienen los productores por vender a un precio mayor
al que estaban dispuestos a vender.
''')
print(f"EP = {EP:.2f}")
# Out:
# EP: Es el beneficio que obtienen los productores por vender a un precio mayor
# al que estaban dispuestos a vender.
#
# EP = 85.95

# %%
# Paso 9 Excedente Total (ET)
ET = EC + EP # type: ignore

print('''
ET: Es la suma del beneficio que obtienen los consumidores y los productores,
representando el bienestar total generado por el mercado.
''')
print(f"ET = EC + EP = {ET:.2f}")
# Out:
# ET: Es la suma del beneficio que obtienen los consumidores y los productores,
# representando el bienestar total generado por el mercado.
#
# ET = EC + EP = 375.03

# %% [markdown]
# ### 2. Graficar ambas funciones en un mismo gráfico, donde el eje vertical debe ser el precio y el horizontal la cantidad.

# %%
# Paso 1: Creo dominio y variables
# Valor máximo en el eje x para mejor visualización
x_max = q_eq
x_max = x_y_max (x_max, 1.5, 'x')

# Valor máximo en el eje y para mejor visualización
y_max = int(float(P_d.subs(q, 0)))
y_max = x_y_max (y_max, 10, 'y')

# Dominio del eje 'X'
q_grid = np.linspace(0, x_max, 500)

# %%
# Paso 2: Convierto funciones simbólicas a numéricas
P_d_num = sp.lambdify(q, P_d, 'numpy')
P_s_num = sp.lambdify(q, P_s, 'numpy')

# %%
# Preparo datos para graficar
P_d_vals = P_d_num(q_grid)
P_s_vals = P_s_num(q_grid)

# %%
# Creo el Gráfico
plt.figure(figsize=(12, 6))
plt.plot(q_grid, P_d_vals, label='$P_d(q) = 100 - q^2$', linewidth=2.5, color='blue')
plt.plot(q_grid, P_s_vals, label='$P_s(q) = 20 + 3q$', linewidth=2.5, color='red')

# Punto de equilibrio
plt.scatter([q_eq], [p_eq], s=200, c='green', marker='*', zorder=5, label=f'Equilibrio ({float(q_eq):.2f}, {float(p_eq):.2f})') # type: ignore
plt.vlines(q_eq, 0, p_eq, linestyles='--', color='black', alpha=0.6) # type: ignore
plt.hlines(p_eq, 0, q_eq, linestyles='--', color='black', alpha=0.6) # type: ignore

plt.title('Oferta, Demanda y Punto de Equilibrio', fontsize=14, fontweight='bold')
plt.xlabel('Cantidad (q)', fontsize=12)
plt.ylabel('Precio (P)', fontsize=12)
plt.legend(fontsize=10, loc='best')
plt.grid(True, alpha=0.8, linestyle='--')
plt.xlim(0, x_max)
plt.ylim(0, y_max)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Sombrear las áreas correspondientes a los excedentes encontrados indicando en el gráfico cuál es el excedente del consumidor y cuál el del productor e interpretar

# %%
# Paso 1 Preparo los datos para graficar

# Valor máximo en el eje x para mejor visualización
x_max = int(float(q_eq)) # type: ignore
x_max = x_y_max (x_max, 1.5, 'x')

# Valor máximo en el eje y para mejor visualización
y_max = int(float(P_d.subs(q, 0)))
y_max = x_y_max (y_max, 10, 'y')

q_grid = np.linspace(0, x_max, 500)

# %%
P_d_num = sp.lambdify(q, P_d, 'numpy')
P_s_num = sp.lambdify(q, P_s, 'numpy')

P_d_vals = P_d_num(q_grid)
P_s_vals = P_s_num(q_grid)

# %%
# Creo Gráfico
plt.figure(figsize=(12, 6))
plt.plot(q_grid, P_d_vals, label='$P_d(q) = 100 - q^2$', linewidth=2.5, color='blue')
plt.plot(q_grid, P_s_vals, label='$P_s(q) = 20 + 3q$', linewidth=2.5, color='red')

# Punto de equilibrio
plt.scatter([q_eq], [p_eq], s=100, c='black', zorder=5, label=f'Equilibrio ({float(q_eq):.2f}, {float(p_eq):.2f})') # type: ignore
plt.vlines(q_eq, 0, p_eq, linestyles='--', color='gray', alpha=0.7) # type: ignore
plt.hlines(p_eq, 0, q_eq, linestyles='--', color='gray', alpha=0.7) # type: ignore

# Sombrear excedentes
condicion = (q_grid <= float(q_eq)).tolist()
plt.fill_between(q_grid, P_d_vals, float(p_eq), where=condicion, 
                 alpha=0.3, color='skyblue', label=f'EC = {float(EC):.2f}') # type: ignore
plt.fill_between(q_grid, float(p_eq), P_s_vals, where=condicion, 
                 alpha=0.3, color='lightcoral', label=f'EP = {float(EP):.2f}') # type: ignore

plt.title('Excedente del Consumidor y del Productor', fontsize=14, fontweight='bold')
plt.xlabel('Cantidad (q)', fontsize=12)
plt.ylabel('Precio (P)', fontsize=12)
plt.legend(fontsize=10, loc='best')
plt.grid(True, alpha=0.8, linestyle='--')
plt.xlim(0, x_max)
plt.ylim(0, y_max)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación:**
#
# **Excedente del Consumidor (EC = 289.08):** Representa el beneficio neto que obtienen los consumidores al comprar el bien a un precio de equilibrio de $42.71, en lugar del precio máximo que estarían dispuestos a pagar según la curva de demanda $P_d(q) = 100 - q^2$. Este ahorro de $289.08 refleja la diferencia entre la valoración subjetiva del bien y el precio de mercado.
#
# **Excedente del Productor (EP = 85.95):** Refleja el beneficio adicional que reciben los productores al vender a $42.71 por unidad, superando el precio mínimo que aceptarían según su curva de oferta $P_s(q) = 20 + 3q$. Este excedente de $85.95 representa la ganancia por encima de sus costos marginales de producción.
#
# **Excedente Total (ET = 375.03):** La suma de ambos excedentes ($289.08 + $85.95 = $375.03) mide el bienestar social total generado por el mercado cuando opera en equilibrio. Este valor representa la eficiencia económica alcanzada cuando se intercambian 7.57 unidades al precio de $42.71.
#
# **Conclusión:** El análisis muestra que el excedente del consumidor es aproximadamente 3.4 veces mayor que el excedente del productor (289.08/85.95 ≈ 3.36). Esto indica que, en esta configuración de mercado, los consumidores capturan la mayor porción del bienestar generado por el intercambio. La estructura particular de las funciones de oferta y demanda (demanda cóncava vs. oferta lineal) favorece significativamente a los compradores, quienes obtienen el 77.1% del excedente total mientras que los productores retienen solo el 22.9%.

# %% [markdown]
# ---
#
# ## Ejercicio 3
#
# ---
#
# Dada la función de Costo marginal
#
# $$Cmg=0.02-300/x^2$$
#
# 1- Hallar la función de Costo total.
#
# 2- Calcular el costo total de producir 80 unidades si el costo fijo asciende a F=70
#
# 3- Calcular, a través de una integral definida, el costo total variable acumulado entre 20 y 35 unidades
#
# 4- Graficar costo total y costo marginal. Interpretar el gráfico.

# %% [markdown]
# ### 1. Hallar la función de Costo total.

# %%
# Integro para hallar la función de Costo Total
# Paso 1: Defino las variables simbólicas
q = sp.symbols('q', positive=True)
F = sp.symbols('F')
q, F
# Out:
# (q, F)

# %%
# Paso 2: Defino la función de Costo Marginal
CMg = 0.02 - (300.0 / q**2)
CMg
# Out:
# 0.02 - 300.0/q**2

# %%
# Paso 3: Integro la función de Ingreso Marginal para obtener la función de Ingreso Total
C = sp.integrate(CMg, q) + F
C = sp.simplify(C)
C
# Out:
# F + 0.02*q + 300.0/q

# %%
# Paso 4: Sustituyo F en la función de Costo Total
C = C.subs(F, 70.0)
C = C.simplify()
C
# Out:
# 0.02*q + 70.0 + 300.0/q

# %% [markdown]
# ### 2. Calcular el costo total de producir 80 unidades si el costo fijo asciende a F=70

# %%
# Sustituyo q = 80 en la función de Costo Total
C_80 = C.subs(q, 80.0)
print(f"""
El costo de producir 80 unidades con un
costo fijo de 70,0 unidades monetarias es
C(80) = {C_80:.2f}
      """)
# Out:
# El costo de producir 80 unidades con un
# costo fijo de 70,0 unidades monetarias es
# C(80) = 75.35

# %% [markdown]
# ### 3. Calcular, a través de una integral definida, el costo total variable acumulado entre 20 y 35 unidades

# %%
# Costo acumulado entre 30 y 45 unidades
C_acum = sp.integrate(CMg, (q, 20, 35))
C_acum = round(C_acum, 2)

# %%
print(f"""
El costo total variable acumulado entre 20 y 35 unidades es de
{C_acum:.2f}
      """)
# Out:
# El costo total variable acumulado entre 20 y 35 unidades es de
# -6.13

# %% [markdown]
# ### 4. Graficar costo total y costo marginal. Interpretar el gráfico.

# %%
# Preparar datos para graficar
x_max = 15
q_grid = np.linspace(0.1, x_max, 500)
C_num = sp.lambdify(q, C)(q_grid)
CMg_num = sp.lambdify(q, CMg)(q_grid)

# Crear figura con tamaño adecuado
plt.figure(figsize=(12, 6))

# Graficar costo total y costo marginal
plt.plot(q_grid, C_num, label='$C(q) = \\frac{300}{q} + 0.02q + 70$', 
         linewidth=2.5, color='blue')
plt.plot(q_grid, CMg_num, label='$CMg(q) = \\frac{-300}{q^2} + 0.02$', 
         linewidth=2.5, color='red')

# Líneas de referencia
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)

# Configuración del gráfico
plt.grid(True, alpha=0.3, linestyle='--')
plt.xlabel('Cantidad (q)', fontsize=12, fontweight='bold')
plt.ylabel('Costo ($)', fontsize=12, fontweight='bold')
plt.title('Función de Costo Total y Costo Marginal', 
         fontsize=14, fontweight='bold', pad=15)
plt.legend(fontsize=11, loc='upper right', framealpha=0.95)
plt.xlim(0, x_max)
plt.ylim(-500, 500)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación Económica del Gráfico:**
#
# **1. Comportamiento del Costo Marginal CMg(q):**
#
# La función de costo marginal $CMg(q) = 0.02 - \frac{300}{q^2}$ presenta dos zonas claramente diferenciadas:
#
# - **Zona de Costos Marginales Negativos (q < 12.25 unidades):** En este rango, el costo marginal es negativo, lo que significa que cada unidad adicional producida **reduce el costo total**. Este comportamiento atípico refleja fuertes **economías de escala** donde los costos fijos ($70) se distribuyen entre más unidades, generando eficiencias significativas.
#
# - **Zona de Costos Marginales Positivos (q > 12.25 unidades):** A partir de q ≈ 12.25, el costo marginal se vuelve positivo, indicando que producir unidades adicionales incrementa el costo total. Sin embargo, el CMg tiende asintóticamente a $0.02, estabilizándose en un costo prácticamente constante para grandes volúmenes de producción.
#
# **2. Punto Crítico de Minimización del Costo Total:**
#
# El **punto mínimo de la función de costo total C(q)** ocurre donde **CMg(q) = 0**, aproximadamente en **q ≈ 12.25 unidades**. En este punto:
#
# $$CMg(12.25) = 0.02 - \frac{300}{12.25^2} \approx 0$$
#
# Este es el nivel de producción más eficiente desde la perspectiva del costo unitario, donde la empresa aprovecha al máximo las economías de escala antes de que los costos variables comiencen a incrementar el costo total.
#
# **3. Comportamiento Asintótico del Costo Total:**
#
# Para grandes cantidades (q > 50), la función de costo total se aproxima a:
#
# $$C(q) \approx 0.02q + 70$$
#
# Esto indica que el costo total crece **linealmente** con una pendiente muy pequeña ($0.02), reflejando que el componente variable del costo es prácticamente constante. Para q = 80 unidades:
#
# $$C(80) = \$75.35$$
#
# El costo fijo de $70 representa el **92.9%** del costo total, dominando la estructura de costos incluso para volúmenes considerables.
#
# **4. Costo Variable Acumulado entre 20 y 35 unidades:**
#
# Mediante integración definida:
#
# $$\int_{20}^{35} CMg(q) \, dq = -6.13$$
# Este resultado **negativo** confirma que en este rango específico, incrementar la producción de 20 a 35 unidades **reduce el costo total** debido a que el costo marginal promedio es negativo en ese intervalo.
#
# **Conclusión:**
#
# La estructura de costos presenta una característica inusual donde **aumentar la producción inicial reduce el costo total** hasta aproximadamente 12.25 unidades, punto a partir del cual el costo comienza a crecer de manera lineal y muy gradual. Esta configuración sugiere que la empresa debe operar a escalas superiores a 12.25 unidades para minimizar sus costos unitarios, y que los **costos fijos dominan la estructura económica** del negocio.

# %% [markdown]
# ---
#
# ### Ejercicio 4
#
# ---
#
# A partir del cash flow MENSUAL establecido en la línea de código propuesta a continuación y considerando un costo de capital anual del 10% ,realice un análisis que contenga:
#
# 1- Métricas financieras: VAN, TIR, TIRM y PAYBACK DESCONTADO e interprete cada una de ellas.
#
# 2- Grafique el flujo de fondos
#
# 3- Grafique el Van a diferentes tasas de descuento de costo del capital (marque en dicho gráfico la TIR y explíquelo)
#
# 4- Considere que el gerente financiero pronostica un aumento posible del costo de capital a la hora de iniciar el proyecto conformando un costo total del 15% anual. Realice el análisis nuevamente e interprete los resultados.
#
# 5- Haga un gráfico comparativo de ambas situaciones

# %%
inversion_inicial = -60000
cash_flows = [
    12000, -10000, 18000, 20000, 25000, 23000, 28000, 30000, -25000, 35000,
    -7000, 12000, 15000, 18000, -20000, 22000, -26000, 29000, -20000, 35000,
    -9000, 13000, -16000, 19000, 22000, 25000, 28000, -28000, 35000
]
nuevo_cash_flow = [inversion_inicial] + cash_flows

# %% [markdown]
# ### 1. Métricas financieras: VAN, TIR, TIRM y PAYBACK DESCONTADO e interprete cada una de ellas.

# %%
# Tasa de descuento anual
TEA = 0.10  # 10% anual

# Definir la tasa de descuento mensual
# NOTA: uso estos valores (365 y 30) para calcular las tasas
# equivalentes anuales y mensuales porque son los usados en clases,
# sin embargo prefiero usar 12 y 1 como períodos de capitalización
# mensual y anual para realizar los cálculos de tasas equivalentes
# mensual y anual

r = tasa_equivalente(TEA, 30, 365) # La fórmula está al inicio de esta notebook
print(f"Tasa efectiva mensual equivalente: TEA {TEA:.2%} → TEM {r:.4%}")
# Out:
# Tasa efectiva mensual equivalente: TEA 10.00% → TEM 0.7864%

# %%
# VAN
van = nf.npv(r, nuevo_cash_flow)
print(f"Tasa de descuento mensual utilizada: {r:.4%}")
print(f"El proyecto genera un valor actual neto de ${van:,.2f}.")
# Out:
# Tasa de descuento mensual utilizada: 0.7864%
# El proyecto genera un valor actual neto de $211,914.79.

# %% [markdown]
# **Interpretación:** El VAN es mayor que cero (VAN>0). Esto implica que el proyecto creará valor para la empresa, ya que el valor presente de todos los flujos de caja futuros supera la inversión inicial. Segun el VAN el proyecto es rentable

# %%
# TIR
tir = nf.irr(values=nuevo_cash_flow)

# NOTA: uso estos valores (365 y 30) para calcular las tasas
# equivalentes anuales y mensuales porque son los usados en clases,
# sin embargo prefiero usar 12 y 1 como períodos de capitalización
# mensual y anual para realizar los cálculos de tasas equivalentes
# mensual y anual

tir_anual = tasa_equivalente(tir, 365, 30) 

print(f"TIR mensual: {tir:.2%}")
print(f"TEM: {r:.2%}")
print(f"TIR anual: {tir_anual:.2%}")
print(f'VIABLE: La TIR ({tir_anual:.2%}) supera el costo de capital ({TEA:.2%}).')
# Out:
# TIR mensual: 20.16%
# TEM: 0.79%
# TIR anual: 834.08%
# VIABLE: La TIR (834.08%) supera el costo de capital (10.00%).

# %% [markdown]
# **Interpretacion:** La TIR (mensual) es mucho mayor que la tasa de descuento (mensual) (20.16% > 0,79%). Esto significa que la rentabilidad intrínseca del proyecto está muy por encima del rendimiento mínimo exigido. Segun el TIR el proyecto es rentable

# %%
# TIRM
# finance_rate: costo de financiar flujos negativos (costo de capital) - USAR TIR
# reinvest_rate: tasa de reinversión de flujos positivos (costo de oportunidad) - USAR r

tirm = nf.mirr(values=nuevo_cash_flow, finance_rate=tir, reinvest_rate=r)

# NOTA: uso estos valores (365 y 30) para calcular las tasas
# equivalentes anuales y mensuales porque son los usados en clases,
# sin embargo prefiero usar 12 y 1 como períodos de capitalización
# mensual y anual para realizar los cálculos de tasas equivalentes
# mensual y anual

tirm_anual = tasa_equivalente(tirm, 365, 30)

print(f"TIRM mensual: {tirm:.4%}")
print(f"TEM: {r:.2%}")
print(f"TIRM anual: {tirm_anual:.2%}")

print(f"\nInterpretación: La rentabilidad modificada es {tirm_anual:.2%} anual.")
print("Es más conservadora que la TIR porque asume reinversión al costo de capital.")
print(f'VIABLE: La TIRM ({tirm_anual:.2%}) supera el costo de capital ({TEA:.2%}).')
# Out:
# TIRM mensual: 6.8295%
# TEM: 0.79%
# TIRM anual: 123.40%
#
# Interpretación: La rentabilidad modificada es 123.40% anual.
# Es más conservadora que la TIR porque asume reinversión al costo de capital.
# VIABLE: La TIRM (123.40%) supera el costo de capital (10.00%).

# %% [markdown]
# **Interpretacion:** La TIRM mensual es mayor que la tasa de descuento mensual (6,83%>0,79%). Esto indica que la rentabilidad efectiva del proyecto, asumiendo que tanto los flujos de caja positivos se reinvierten a una tasa de reinversion como que los flujos de caja negativos se financian a una tasa de financiamiento, supera al costo de capital. *Segun el TIRM el proyecto es rentable*.

# %%
# Período de Recuperación Descontado (PRD) - Fórmula corregida
prd = payback_desc(nuevo_cash_flow, r) # La fórmula está al inicio de esta notebook
print(f"Payback descontado: {prd:.2f} meses ({prd/12:.2f} años)" if prd is not None else "📊 Payback descontado: No se recupera la inversión")
# Out:
# Payback descontado: 4.87 meses (0.41 años)

# %% [markdown]
# **Interpretación del Período de Recuperación Descontado (PRD):**
#
# El PRD indica que la **inversión inicial de $60,000** se recupera en **4.87 meses** cuando se consideran los flujos de caja descontados a la tasa mensual del 0.79%.
#
# **Análisis:**
#
# - **Tiempo de recuperación:** 4.87 meses (aproximadamente 5 meses)
# - **Criterio de aceptación:** PRD < 24 meses → **Proyecto viable**
# - **Interpretación:** Un PRD corto (5 meses) indica **bajo riesgo temporal**, ya que la inversión se recupera rápidamente, reduciendo la exposición a incertidumbres futuras.
#
# **Conclusión:**
#
# La empresa recupera su inversión inicial en menos de 5 meses, lo que confirma que el proyecto es seguro desde la perspectiva de liquidez y rentabilidad temporal.

# %% [markdown]
# ### 2. Grafique el flujo de fondos

# %%
# Visualización
years = list(range(len(nuevo_cash_flow)))
plt.figure(figsize=(12, 6))
colores = ['red' if f < 0 else 'green' for f in nuevo_cash_flow]
plt.bar(years, nuevo_cash_flow, color=colores, alpha=0.7, edgecolor='black')
plt.axhline(0, color='black', linewidth=1)
plt.title(f'Flujos de Caja | VAN = ${van:,.0f}', fontweight='bold')
plt.xlabel('Mes')
plt.ylabel('Flujo ($)')
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis del Flujo de Fondos:**
#
# El gráfico muestra la estructura de flujos de caja del proyecto durante 30 períodos (inversión inicial + 29 meses operativos).
#
# **Características principales:**
#
# - **Inversión inicial:** $60,000 (mes 0)
# - **Flujos positivos:** 20 meses (69.0%)
# - **Flujos negativos:** 9 meses (31.0%)
# - **Suma total de flujos:** $303,000
#
# **Interpretación:**
#
# El proyecto presenta **alta volatilidad** con flujos mixtos distribuidos irregularmente. Los principales flujos negativos ocurren en los meses 29 (-$28,000), 18 (-$26,000), 10 (-$25,000), 16 (-$20,000) y 20 (-$20,000), reflejando necesidades periódicas de capital de trabajo.
#
# A pesar de esta irregularidad, la suma total de $303,000 supera ampliamente la inversión inicial de $60,000, generando un beneficio bruto de $243,000. Esta estructura de flujos requiere una gestión activa de liquidez para cubrir los períodos con salidas de efectivo, especialmente durante los meses 29, 18 y 10 donde se concentran las mayores necesidades de financiamiento.

# %% [markdown]
# ### 3. Grafique el Van a diferentes tasas de descuento de costo del capital (marque en dicho gráfico la TIR y explíquelo)

# %%
# Calcular TIR y TIRM

flujos = nuevo_cash_flow.copy()
van_tirm = nf.npv(tirm, nuevo_cash_flow)

print(f"Tasa Interna de Retorno (TIR): {tir:.2%}")
print(f"Tasa Interna de Retorno Modificada (TIRM): {tirm:.2%}")

# --- Crear rango de tasas para VAN ---
tasas_descuento = np.arange(0, max(tir*1.2, 0.25), 0.0028) # es muy importante agregar el max porque sino el grafico no encuentra el corte con la tir, queda desescalado.
# --- Calcular VAN para cada tasa ---
van_por_tasa = [nf.npv(tasa, flujos) for tasa in tasas_descuento]

# --- Graficar VAN vs Tasa ---
plt.figure(figsize=(12, 6))
plt.plot(tasas_descuento, van_por_tasa, marker='o', linestyle='-', color='blue', label='VANs')

# Marcar TIR y TIRM en el gráfico
plt.axvline(tir, color='red', linestyle='--', linewidth=1, label=f"TIR = {tir:.2%}")
plt.axhline(0, color='red', linestyle='--', linewidth=1, label=f"VAN_TIR = 0")
plt.axvline(tirm, color='green', linestyle='--', linewidth=1, label=f"TIRM = {tirm:.2%}")
plt.axhline(van_tirm, color='green', linestyle='--', linewidth=1, label=f"VAN_TIRM = {van_tirm:.2f}")

# grafico el punto del VAN del proyecto
plt.plot(r, van, marker='*', color='purple', markersize=8, label=f"VAN = {van:.2f}")
plt.axvline(r, color='purple', linestyle='--', linewidth=1)
plt.axhline(van, color='purple', linestyle='--', linewidth=1)

# --- Etiquetas y formato ---
plt.title('Valor Actual Neto (VAN) a Diferentes Tasas de Descuento')
plt.xlabel('Tasa de Descuento Mensual (r/100)')
plt.ylabel('VAN')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Tasa Interna de Retorno (TIR): 20.16%
# Tasa Interna de Retorno Modificada (TIRM): 6.83%

# %% [markdown]
# **Análisis del Gráfico VAN vs Tasa de Descuento:**
#
# El gráfico muestra la relación inversa entre el VAN y la tasa de descuento: a mayor tasa, menor VAN. La curva cruza el eje horizontal (VAN=0) en el punto **TIR = 20.16%**, que representa la tasa máxima que el proyecto puede soportar antes de dejar de ser rentable.
#
# Al evaluar el proyecto con la tasa de descuento del **0.79% mensual** (equivalente al 10% anual), el punto correspondiente en la curva del VAN (marcado en morado) se encuentra muy por encima de la línea horizontal de VAN=0, generando un valor positivo de $211,914.79.
#
# La línea verde marca la **TIRM = 6.83%**, que representa una evaluación más conservadora de la rentabilidad al asumir reinversión de flujos al costo de capital en lugar de la TIR.
#
# **Conclusión:** El gráfico confirma visualmente que el proyecto es altamente viable, ya que el VAN se mantiene positivo mientras la tasa de descuento sea inferior a 20.16%. Con el costo de capital actual (0.79% mensual), el proyecto genera valor económico significativo y debe ser aceptado.

# %% [markdown]
# ### 4. Considere que el gerente financiero pronostica un aumento posible del costo de capital a la hora de iniciar el proyecto conformando un costo total del 15% anual. Realice el análisis nuevamente e interprete los resultados.

# %%
TEA_2 = 0.15  # 15% anual
r2 = tasa_equivalente(TEA_2, 30, 365)  # Tasa efectiva mensual
print(f"Nueva TEA: {TEA_2:.2%} → Nueva TEM: {r2:.4%}")

van2 = nf.npv(rate=r2, values=nuevo_cash_flow)
tir2 = nf.irr(values=nuevo_cash_flow)  # TIR no cambia (característica del proyecto)
tirm2 = nf.mirr(values=nuevo_cash_flow, finance_rate=tir2, reinvest_rate=r2)
prd2 = payback_desc(nuevo_cash_flow, r2)
# Out:
# Nueva TEA: 15.00% → Nueva TEM: 1.1554%

# %%
print(f"VAN con nueva tasa de descuento ({r2:.2%}): {van2:.2f}")
print(f"TIR con nueva tasa de descuento: {tir2:.2%}")
print(f"TIRM con nueva tasa de descuento: {tirm2:.2%}")
print(f"Payback descontado con nueva tasa de descuento: {prd2:.2f} meses")
# Out:
# VAN con nueva tasa de descuento (1.16%): 198984.63
# TIR con nueva tasa de descuento: 20.16%
# TIRM con nueva tasa de descuento: 7.02%
# Payback descontado con nueva tasa de descuento: 4.91 meses

# %%
# Creo un cuadro comparativo de métricas financieras
comparacion_data = {
    'Métrica': ['VAN', 'TIR', 'TIRM', 'PBD (meses)'],
    'TEA 10% anual': [f"${van:,.2f}", f"{tir:.2%}", f"{tirm:.2%}", f"{prd:.2f} meses"],
    'TEA 15% anual': [f"${van2:,.2f}", f"{tir2:.2%}", f"{tirm2:.2%}", f"{prd2:.2f} meses"],
    'Diferencia': [f"${van - van2:,.2f}", "Sin cambio", f"{tirm2 - tirm:.2%}", f"{prd2 - prd:.2f} meses"]
}

df_comparacion = pd.DataFrame(comparacion_data)
print("CUADRO COMPARATIVO DE MÉTRICAS FINANCIERAS")
print("=" * 60)
print(df_comparacion.to_string(index=False))
# Out:
# CUADRO COMPARATIVO DE MÉTRICAS FINANCIERAS
# ...
#     Métrica TEA 10% anual TEA 15% anual Diferencia
#         VAN   $211,914.79   $198,984.63 $12,930.16
#         TIR        20.16%        20.16% Sin cambio
#        TIRM         6.83%         7.02%      0.20%
# PBD (meses)    4.87 meses    4.91 meses 0.03 meses

# %% [markdown]
#  **Interpretación Comparativa de Escenarios:**
#
# **VAN:** Cuando el costo de capital sube del 10% al 15%, el VAN baja considerablemente (de $211,914.79 a un valor menor). Sin embargo, el proyecto **sigue siendo rentable** (VAN > 0) en ambos casos, lo que demuestra que el proyecto resiste bien los cambios en el costo de financiamiento.
#
# **TIR:** Se mantiene en **20.16%** en ambos escenarios porque la TIR es una característica propia del proyecto que solo depende de sus flujos de caja, no del costo de capital que usemos. Como la TIR (20.16%) es mayor que ambas tasas (10% y 15%), confirma que el proyecto es rentable en ambos escenarios.
#
# **TIRM:** La TIRM aumenta ligeramente debido a que el proyecto tiene 9 flujos negativos durante su desarrollo. Cuando usamos una tasa de descuento más alta, esos flujos negativos valen menos en el presente, lo que reduce el monto total que hay que financiar y mejora ligeramente la TIRM. En ambos casos, la TIRM supera ampliamente el costo de capital, confirmando la viabilidad del proyecto.
#
# **Payback Descontado:** Aumenta ligeramente de **4.87 meses a aproximadamente 5 meses** debido a que con una tasa de descuento mayor, los flujos futuros valen menos en términos presentes. Sin embargo, la diferencia es mínima y en ambos casos la inversión se recupera muy rápido (menos de medio año), indicando bajo riesgo temporal.
#
# **Conclusión:** El proyecto es viable en ambos escenarios. Aunque con el costo de capital al 15% el VAN disminuye, el proyecto sigue creando valor económico significativo. La recuperación rápida de la inversión (menos de 5 meses en ambos casos) y una TIR muy superior al costo de capital (20.16% vs 10-15%) confirman que el proyecto tiene una estructura financiera sólida y resistente a cambios en las condiciones de financiamiento.

# %% [markdown]
# ### 5. Haga un gráfico comparativo de ambas situaciones

# %%
# Gráfico comparativo de ambos escenarios

# Definimos rango de tasas de descuento
tasas_rango = np.arange(0, 0.25, 0.01)

# Calculamos VAN para cada tasa
van_proyecto_rango = [nf.npv(tasa, nuevo_cash_flow) for tasa in tasas_rango]

# Creo el grafico
plt.figure(figsize=(12, 6))
plt.plot(tasas_rango, van_proyecto_rango, linestyle='-')

# Marcar VAN
plt.plot(r, van, 'ro', markersize=8, label=f'VAN TEA = {TEA*100:.2f}% ({r*100:.2f}% mensual)')
plt.axvline(r, color='red', linestyle='--', linewidth=0.8)
plt.axhline(van, color='red', linestyle='--', linewidth=0.8)
plt.plot(r2, van2, 'go', markersize=8, label=f'VAN TEA_2 = {TEA_2*100:.2f}% ({r2*100:.2f}% mensual)')
plt.axvline(r2, color='green', linestyle='--', linewidth=0.8)
plt.axhline(van2, color='green', linestyle='--', linewidth=0.8)

# Marcar TIR
plt.plot(tir, 0, color='purple', markersize=12, marker='*', label=f'TIR = TIR2 = {tir:.2%}') # Mostrar la TIR

plt.title('Sensibilidad del VAN a la Tasa de Descuento')
plt.xlabel('Tasa de Descuento')
plt.ylabel('VAN')


plt.grid(True)
plt.axhline(0, color='black', linestyle='-', linewidth=1)
plt.legend()
plt.show()

# %% [markdown]
# **Interpretación Comparativa de Escenarios:**
#
# El gráfico de sensibilidad del VAN muestra claramente cómo el valor del proyecto responde a diferentes tasas de descuento. Al comparar ambos escenarios (TEA 10% vs TEA 15%), podemos observar varios puntos clave:
#
# **Análisis del VAN en el Gráfico:**
#
# La curva descendente del VAN confirma la relación inversa con la tasa de descuento. El punto marcado en rojo (TEA 10%, r=0.79% mensual) muestra un VAN de $211,914.79, mientras que el punto verde (TEA 15%, r=1.18% mensual) indica un VAN menor. La distancia vertical entre ambos puntos representa la **pérdida de valor** que experimenta el proyecto cuando el costo de financiamiento aumenta. A pesar de esta caída, **ambos puntos se mantienen muy por encima del eje horizontal (VAN=0)**, lo que confirma viabilidad en ambos escenarios.
#
# **TIR como Punto de Referencia:**
#
# La estrella morada en **20.16%** marca el punto crítico donde VAN=0. Observamos que tanto el escenario al 10% como al 15% están considerablemente a la izquierda de la TIR en el gráfico, lo que significa que existe un **amplio margen de seguridad** (10.16% y 5.16% respectivamente) antes de que el proyecto deje de ser rentable. Esta distancia en el gráfico es una medida visual del riesgo: mientras mayor sea la separación, menor es el riesgo de que cambios en las condiciones de financiamiento vuelvan inviable el proyecto.
#
# **Comportamiento de TIRM:**
#
# El incremento de la TIRM (observable en el desplazamiento del punto verde sobre la curva) se explica por el efecto de los 9 flujos negativos del proyecto. Con tasas de descuento más altas, estos flujos negativos se "descuentan más fuertemente", reduciendo su peso financiero y mejorando ligeramente la rentabilidad modificada. En ambos casos, la TIRM supera ampliamente el costo de capital.
#
# **Estabilidad del Payback:**
#
# El mínimo cambio en el período de recuperación (aproximadamente 4.87 a 5 meses) refleja que la inversión se recupera tan rápidamente que incluso variaciones significativas en la tasa de descuento (50% de aumento: de 10% a 15%) tienen impacto marginal. Esto se debe a que los primeros flujos positivos, que son los que permiten recuperar la inversión, se descuentan muy poco independientemente de la tasa utilizada.
#
# **Conclusión:**
#
# El análisis gráfico revela un proyecto financieramente robusto. La curva del VAN permanece en territorio positivo incluso con incrementos sustanciales en el costo de capital, y la distancia hasta la TIR proporciona un colchón de seguridad considerable. El proyecto es viable en ambos escenarios, manteniendo métricas favorables que lo posicionan como una inversión atractiva bajo diferentes condiciones de financiamiento.

# %% [markdown]
# ---
#
#
# ### Ejercicio 5
#
# ---
# Corra la siguiente celda, que genera el dataset df_supermarket.csv
#
# Usted recibe estos datos y debe formular un informe de evolución de ventas y situación para el equipo directivo. Arme gráficas y genere dicho informe para explicar el desempeño del supermercado durante el 2024.

# %%
# Generación de un CSV de ejemplo para el Ejercicio 5 Adicional (Ventas de Supermercado)
import pandas as pd
import numpy as np

# Crear datos ficticios para un archivo Supermarket_Sales.csv
np.random.seed(42) # para reproducibilidad

productos = ['Leche', 'Yogur', 'Queso', 'Carne Res', 'Pollo', 'Pescado', 'Manzanas', 'Bananas', 'Lechuga', 'Pan Blanco', 'Galletas']
categorias = ['Lácteos', 'Lácteos', 'Lácteos', 'Carnes', 'Carnes', 'Carnes', 'Frutas y Verduras', 'Frutas y Verduras', 'Frutas y Verduras', 'Panadería', 'Panadería']
regiones = ['Norte', 'Sur', 'Este', 'Oeste']

data = {
    'nombre_producto': np.random.choice(productos, 1000),
    'categoria': np.random.choice(categorias, 1000),
    'fecha_venta': pd.to_datetime('2024-01-01') + pd.to_timedelta(np.random.randint(0, 365, 1000), unit='D'),
    'unidades_vendidas_diarias': np.random.randint(10, 200, 1000),
    'precio_unitario': np.round(np.random.uniform(1.5, 50, 1000), 2),
    'costo_unitario': np.round(np.random.uniform(0.5, 30, 1000), 2),
    'region': np.random.choice(regiones, 1000)
}
df_supermarket = pd.DataFrame(data)

df_supermarket['ingreso_bruto_diario'] = df_supermarket['unidades_vendidas_diarias'] * df_supermarket['precio_unitario']
df_supermarket['margen_ganancia_bruto'] = (df_supermarket['precio_unitario'] - df_supermarket['costo_unitario']) * df_supermarket['unidades_vendidas_diarias']
df_supermarket['margen_ganancia_porcentual'] = (df_supermarket['margen_ganancia_bruto'] / df_supermarket['ingreso_bruto_diario']).fillna(0) # Handle division by zero if ingreso_bruto_diario is 0


df_supermarket['cambio_ventas_semanal'] = np.round(np.random.uniform(-15, 20, 1000), 2) # % de cambio
df_supermarket
# Out:
#     nombre_producto          categoria fecha_venta  unidades_vendidas_diarias  \
# 0          Manzanas  Frutas y Verduras  2024-05-26                         10
# 1         Carne Res  Frutas y Verduras  2024-10-13                         96
# 2          Galletas            Lácteos  2024-05-21                        137
# 3           Bananas             Carnes  2024-02-22                         76
# 4             Pollo            Lácteos  2024-10-30                         13
# ..              ...                ...         ...                        ...
# 995      Pan Blanco  Frutas y Verduras  2024-06-04                         31
# 996         Lechuga  Frutas y Verduras  2024-02-16                        110
# 997           Yogur             Carnes  2024-07-19                        164
# 998         Bananas            Lácteos  2024-05-27                        130
# 999         Bananas            Lácteos  2024-05-03                        102
#
# ...

# %% [markdown]
# ### Exploración y Análisis Descriptivo

# %%
# PASO1: Exploración inicial: información general del dataset
print("INFORMACIÓN GENERAL DEL DATASET")
print("=" * 80)
df_supermarket.info()
print("\n" + "=" * 80)
# Out:
# INFORMACIÓN GENERAL DEL DATASET
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   nombre_producto             1000 non-null   object
#  1   categoria                   1000 non-null   object
#  2   fecha_venta                 1000 non-null   datetime64[ns]
#  3   unidades_vendidas_diarias   1000 non-null   int64
#  4   precio_unitario             1000 non-null   float64
#  5   costo_unitario              1000 non-null   float64
#  6   region                      1000 non-null   object
#  7   ingreso_bruto_diario        1000 non-null   float64
#  8   margen_ganancia_bruto       1000 non-null   float64
#  9   margen_ganancia_porcentual  1000 non-null   float64
#  10  cambio_ventas_semanal       1000 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(3)
# memory usage: 86.1+ KB
#
# ...

# %%
# Primeras observaciones del dataset
print("PRIMERAS 10 OBSERVACIONES:")
print("=" * 80)
df_supermarket.head(10)
# Out:
# PRIMERAS 10 OBSERVACIONES:
# ...
#   nombre_producto          categoria fecha_venta  unidades_vendidas_diarias  \
# 0        Manzanas  Frutas y Verduras  2024-05-26                         10
# 1       Carne Res  Frutas y Verduras  2024-10-13                         96
# 2        Galletas            Lácteos  2024-05-21                        137
# 3         Bananas             Carnes  2024-02-22                         76
# 4           Pollo            Lácteos  2024-10-30                         13
# 5        Manzanas  Frutas y Verduras  2024-03-09                        195
# 6      Pan Blanco            Lácteos  2024-12-26                        162
# 7           Queso  Frutas y Verduras  2024-03-30                         56
# 8        Manzanas            Lácteos  2024-08-07                         47
# 9        Galletas            Lácteos  2024-07-10                        152
#
#    precio_unitario  costo_unitario region  ingreso_bruto_diario  \
# ...

# %%
# Verificar valores nulos
print("VERIFICACIÓN DE VALORES NULOS:")
print("=" * 80)
valores_nulos = df_supermarket.isnull().sum()
print(valores_nulos)
print("\nTotal de valores nulos:", valores_nulos.sum())
print("=" * 80)
# Out:
# VERIFICACIÓN DE VALORES NULOS:
# ...
# nombre_producto               0
# categoria                     0
# fecha_venta                   0
# unidades_vendidas_diarias     0
# precio_unitario               0
# costo_unitario                0
# region                        0
# ingreso_bruto_diario          0
# margen_ganancia_bruto         0
# margen_ganancia_porcentual    0
# cambio_ventas_semanal         0
# dtype: int64
#
# Total de valores nulos: 0
# ...

# %%
# PASO 2: Estadísticas descriptivas de variables numéricas
print("ESTADÍSTICAS DESCRIPTIVAS")
print("=" * 80)
df_supermarket.describe().round(2)
# Out:
# ESTADÍSTICAS DESCRIPTIVAS
# ...
#                       fecha_venta  unidades_vendidas_diarias  precio_unitario  \
# count                        1000                    1000.00          1000.00
# mean   2024-06-26 22:20:38.400000                     105.85            25.60
# min           2024-01-02 00:00:00                      10.00             1.50
# 25%           2024-04-01 18:00:00                      58.00            13.57
# 50%           2024-06-16 12:00:00                     107.00            25.60
# 75%           2024-09-23 00:00:00                     155.00            37.60
# max           2024-12-30 00:00:00                     199.00            49.98
# std                           NaN                      55.44            13.89
#
#        costo_unitario  ingreso_bruto_diario  margen_ganancia_bruto  \
# count         1000.00               1000.00                1000.00
# mean            15.00               2758.46                1156.48
# ...

# %% [markdown]
# **Conclusión:** El dataset contiene 1000 registros sin valores nulos, distribuidos uniformemente a lo largo de 2024. Las variables numéricas muestran alta variabilidad en ventas (std ≈ 2300) y unidades (std ≈ 53), con precios entre $1.50 y $50, mientras que los márgenes porcentuales presentan valores negativos promedio, indicando que algunos costos superan los precios en ciertas transacciones.

# %%
# PASO 3: Crear variables temporales para análisis dimensional
df_supermarket['mes'] = df_supermarket['fecha_venta'].dt.month
df_supermarket['trimestre'] = df_supermarket['fecha_venta'].dt.quarter
df_supermarket['dia_semana'] = df_supermarket['fecha_venta'].dt.dayofweek
df_supermarket['nombre_mes'] = df_supermarket['fecha_venta'].dt.month_name()

print("Variables temporales creadas: mes, trimestre, dia_semana, nombre_mes")
print("\nPrimeras observaciones:")
df_supermarket[['fecha_venta', 'mes', 'trimestre', 'nombre_mes']].head()
# Out:
# Variables temporales creadas: mes, trimestre, dia_semana, nombre_mes
#
# Primeras observaciones:
#   fecha_venta  mes  trimestre nombre_mes
# 0  2024-05-26    5          2        May
# 1  2024-10-13   10          4    October
# 2  2024-05-21    5          2        May
# 3  2024-02-22    2          1   February
# 4  2024-10-30   10          4    October

# %% [markdown]
# **Conclusión:** Las 4 categorías están balanceadas (Lácteos 285, Frutas y Verduras 276, Carnes 258, Panadería 181), al igual que las 4 regiones (Sur 271, Norte 255, Oeste 252, Este 222). Los 11 productos presentan frecuencias similares (71-110 registros), sugiriendo una distribución equilibrada de las transacciones entre productos, aunque Leche (110) y Galletas (71) marcan los extremos.

# %%
# Verificar valores únicos en variables categóricas
print("RESUMEN DE VARIABLES CATEGÓRICAS")
print("=" * 80)

print(f"\nCategorías ({df_supermarket['categoria'].nunique()}):")
print(df_supermarket['categoria'].value_counts())

print(f"\nRegiones ({df_supermarket['region'].nunique()}):")
print(df_supermarket['region'].value_counts())

print(f"\nProductos ({df_supermarket['nombre_producto'].nunique()}):")
print(df_supermarket['nombre_producto'].value_counts())
# Out:
# RESUMEN DE VARIABLES CATEGÓRICAS
# ...
#
# Categorías (4):
# categoria
# Lácteos              285
# Frutas y Verduras    276
# Carnes               258
# Panadería            181
# Name: count, dtype: int64
#
# Regiones (4):
# region
# Sur      271
# Norte    255
# Oeste    252
# Este     222
# Name: count, dtype: int64
#
# Productos (11):
# nombre_producto
# Leche         110
# Queso         103
# Pollo         102
# Pan Blanco    100
# Bananas        90
# Lechuga        88
# Pescado        87
# Manzanas       86
# Carne Res      84
# Yogur          79
# Galletas       71
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ### Análisis Dimensional y Agregaciones

# %%
# PASO 4: Agregación por categoría: ventas totales, margen promedio y unidades vendidas
categoria_agg = df_supermarket.groupby('categoria').agg({
    'ingreso_bruto_diario': 'sum',
    'margen_ganancia_porcentual': 'mean',
    'unidades_vendidas_diarias': 'sum',
    'precio_unitario': 'mean'
}).round(2)

categoria_agg.columns = ['Ventas Totales ($)', 'Margen Promedio (%)', 
                          'Unidades Vendidas', 'Precio Promedio ($)']

print("RESUMEN POR CATEGORÍA")
print("=" * 80)
print(categoria_agg.sort_values('Ventas Totales ($)', ascending=False))

# Calcular participación de cada categoría
categoria_agg['Participación (%)'] = (
    categoria_agg['Ventas Totales ($)'] / categoria_agg['Ventas Totales ($)'].sum() * 100
).round(2)

print("\nParticipación de ventas por categoría:")
print(categoria_agg[['Ventas Totales ($)', 'Participación (%)']]
      .sort_values('Participación (%)', ascending=False))
# Out:
# RESUMEN POR CATEGORÍA
# ...
#                    Ventas Totales ($)  Margen Promedio (%)  Unidades Vendidas  \
# categoria
# Frutas y Verduras           759059.50                -0.17              29273
# Carnes                      745143.75                -0.09              26973
# Lácteos                     725609.97                -0.10              30162
# Panadería                   528648.65                -0.05              19446
#
#                    Precio Promedio ($)
# categoria
# Frutas y Verduras                25.21
# Carnes                           26.50
# Lácteos                          24.24
# Panadería                        27.04
#
# Participación de ventas por categoría:
#                    Ventas Totales ($)  Participación (%)
# categoria
# Frutas y Verduras           759059.50              27.52
# Carnes                      745143.75              27.01
# Lácteos                     725609.97              26.30
# ...

# %%
# PASO 5: Agregación por región: desempeño comercial
region_agg = df_supermarket.groupby('region').agg({
    'ingreso_bruto_diario': ['sum', 'mean'],
    'margen_ganancia_porcentual': 'mean',
    'unidades_vendidas_diarias': 'sum'
}).round(2)

region_agg.columns = ['Ventas Totales ($)', 'Venta Promedio ($)', 
                      'Margen Promedio (%)', 'Unidades Totales']

print("DESEMPEÑO POR REGIÓN")
print("=" * 80)
print(region_agg.sort_values('Ventas Totales ($)', ascending=False))

# Identificar región líder
region_top = region_agg['Ventas Totales ($)'].idxmax()
ventas_top = region_agg.loc[region_top, 'Ventas Totales ($)']
print(f"\nRegión líder: {region_top} con ${ventas_top:,.2f} en ventas totales")
# Out:
# DESEMPEÑO POR REGIÓN
# ...
#         Ventas Totales ($)  Venta Promedio ($)  Margen Promedio (%)  \
# region
# Norte            743078.62             2914.03                 0.10
# Sur              730835.28             2696.81                -0.28
# Oeste            707894.02             2809.10                -0.12
# Este             576653.95             2597.54                -0.10
#
#         Unidades Totales
# region
# Norte              27132
# Sur                28563
# Oeste              27595
# Este               22564
#
# Región líder: Norte con $743,078.62 en ventas totales
#         Ventas Totales ($)  Venta Promedio ($)  Margen Promedio (%)  \
# region
# Norte            743078.62             2914.03                 0.10
# Sur              730835.28             2696.81                -0.28
# Oeste            707894.02             2809.10                -0.12
# Este             576653.95             2597.54                -0.10
#
#         Unidades Totales
# region
# ...

# %% [markdown]
# **Conclusión:** Frutas y Verduras lidera con 27.52% de las ventas totales, seguida por Carnes (27.01%) y Lácteos (26.30%). La región Norte domina con $743,079 en ventas. El producto más vendido es Leche ($288,484), y existe alta estacionalidad con Mayo superando a Noviembre en un 73.26%, lo que evidencia la necesidad de ajustar inventarios y estrategias promocionales según la época del año.

# %%
# PASO 6: Ranking de Productos. Top 10 productos por ventas
producto_agg = df_supermarket.groupby('nombre_producto').agg({
    'ingreso_bruto_diario': 'sum',
    'margen_ganancia_porcentual': 'mean',
    'unidades_vendidas_diarias': 'sum',
    'categoria': 'first'
}).round(2)

producto_agg.columns = ['Ventas Totales ($)', 'Margen Promedio (%)', 
                        'Unidades Vendidas', 'Categoría']

print("TOP 10 PRODUCTOS POR VENTAS")
print("=" * 80)
top10_productos = producto_agg.sort_values('Ventas Totales ($)', ascending=False).head(10)
print(top10_productos)

# Producto más vendido
producto_top = producto_agg['Ventas Totales ($)'].idxmax()
ventas_producto_top = producto_agg.loc[producto_top, 'Ventas Totales ($)']
categoria_producto_top = producto_agg.loc[producto_top, 'Categoría']

print(f"\nProducto líder: '{producto_top}' ({categoria_producto_top})")
print(f"   Ventas: ${ventas_producto_top:,.2f}")
# Out:
# TOP 10 PRODUCTOS POR VENTAS
# ...
#                  Ventas Totales ($)  Margen Promedio (%)  Unidades Vendidas  \
# nombre_producto
# Leche                     288483.52                -0.17              11506
# Pollo                     271188.96                -0.00              10513
# Queso                     268396.27                -0.07              10242
# Lechuga                   264676.94                -0.40               9897
# Manzanas                  254263.51                -0.00               9454
# Pescado                   252466.50                -0.05               9696
# Pan Blanco                251329.40                -0.11              10587
# Carne Res                 242650.45                 0.26               8485
# Bananas                   233054.13                -0.16               9001
# Yogur                     228812.28                -0.34               8847
#
#                          Categoría
# nombre_producto
# ...

# %%
# PASO 7: Evolución mensual de ventas
ventas_mensuales = df_supermarket.groupby('mes').agg({
    'ingreso_bruto_diario': 'sum',
    'margen_ganancia_porcentual': 'mean'
}).round(2)

ventas_mensuales.columns = ['Ventas Totales ($)', 'Margen Promedio (%)']

print("EVOLUCIÓN MENSUAL DE VENTAS (2024)")
print("=" * 80)
print(ventas_mensuales)

# Identificar mejor y peor mes
mejor_mes = ventas_mensuales['Ventas Totales ($)'].idxmax()
peor_mes = ventas_mensuales['Ventas Totales ($)'].idxmin()
ventas_mejor_mes = ventas_mensuales.loc[mejor_mes, 'Ventas Totales ($)']
ventas_peor_mes = ventas_mensuales.loc[peor_mes, 'Ventas Totales ($)']

meses_nombres = {1:'Enero', 2:'Febrero', 3:'Marzo', 4:'Abril', 5:'Mayo', 6:'Junio',
                7:'Julio', 8:'Agosto', 9:'Septiembre', 10:'Octubre', 11:'Noviembre', 12:'Diciembre'}

print(f"\nMejor mes: {meses_nombres[mejor_mes]} (${ventas_mejor_mes:,.2f})")
print(f"Peor mes: {meses_nombres[peor_mes]} (${ventas_peor_mes:,.2f})")
print(f"Variación: {((ventas_mejor_mes - ventas_peor_mes) / ventas_peor_mes * 100):.2f}%")
# Out:
# EVOLUCIÓN MENSUAL DE VENTAS (2024)
# ...
#      Ventas Totales ($)  Margen Promedio (%)
# mes
# 1             192648.90                -0.18
# 2             203423.98                -0.10
# 3             237512.88                -0.21
# 4             252941.60                -0.33
# 5             311295.08                -0.01
# 6             228872.08                 0.06
# 7             204187.28                -0.21
# 8             241023.35                -0.06
# 9             254808.23                 0.02
# 10            267247.22                -0.16
# 11            179664.52                -0.03
# 12            184836.75                -0.03
#
# Mejor mes: Mayo ($311,295.08)
# Peor mes: Noviembre ($179,664.52)
# Variación: 73.26%

# %% [markdown]
# ---
#
# ### Visualizaciones y Dashboard

# %%
# PASO 8: Dashboard integral con 6 visualizaciones
fig, axes = plt.subplots(3, 2, figsize=(16, 14))
fig.suptitle('DASHBOARD - ANÁLISIS DE VENTAS SUPERMERCADO 2024', 
             fontsize=16, fontweight='bold', y=0.995)

# 1. Ventas por Categoría (Barras)
ax1 = axes[0, 0]
categoria_ventas = df_supermarket.groupby('categoria')['ingreso_bruto_diario'].sum().sort_values(ascending=False)
categoria_ventas.plot(kind='bar', ax=ax1, color='steelblue', edgecolor='black')
ax1.set_title('Ventas Totales por Categoría', fontweight='bold')
ax1.set_xlabel('Categoría')
ax1.set_ylabel('Ventas ($)')
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
for i, v in enumerate(categoria_ventas):
    ax1.text(i, v, f'${v:,.0f}', ha='center', va='bottom', fontsize=9)

# 2. Evolución Temporal (Línea)
ax2 = axes[0, 1]
ventas_mensuales['Ventas Totales ($)'].plot(kind='line', ax=ax2, marker='o', 
                                             color='darkgreen', linewidth=2, markersize=6)
ax2.set_title('Evolución Mensual de Ventas', fontweight='bold')
ax2.set_xlabel('Mes')
ax2.set_ylabel('Ventas ($)')
ax2.set_xticks(range(1, 13))
ax2.grid(True, alpha=0.3)
ax2.axhline(ventas_mensuales['Ventas Totales ($)'].mean(), color='red', 
            linestyle='--', label='Promedio', linewidth=1.5)
ax2.legend()

# 3. Distribución de Márgenes (Histograma)
ax3 = axes[1, 0]
ax3.hist(df_supermarket['margen_ganancia_porcentual'], bins=20, color='coral', 
         edgecolor='black', alpha=0.7)
ax3.set_title('Distribución de Márgenes Porcentuales', fontweight='bold')
ax3.set_xlabel('Margen (%)')
ax3.set_ylabel('Frecuencia')
ax3.axvline(df_supermarket['margen_ganancia_porcentual'].mean(), color='darkred', 
            linestyle='--', label=f'Media: {df_supermarket["margen_ganancia_porcentual"].mean():.2f}%', linewidth=2)
ax3.grid(True, alpha=0.3)
ax3.legend()

# 4. Top 10 Productos (Barras horizontales)
ax4 = axes[1, 1]
top10_productos['Ventas Totales ($)'].plot(kind='barh', ax=ax4, color='purple', edgecolor='black')
ax4.set_title('Top 10 Productos por Ventas', fontweight='bold')
ax4.set_xlabel('Ventas ($)')
ax4.set_ylabel('Producto')
ax4.grid(True, alpha=0.3, axis='x')

# 5. Desempeño Regional (Barras)
ax5 = axes[2, 0]
region_ventas = df_supermarket.groupby('region')['ingreso_bruto_diario'].sum().sort_values(ascending=False)
region_ventas.plot(kind='bar', ax=ax5, color='teal', edgecolor='black')
ax5.set_title('Ventas por Región', fontweight='bold')
ax5.set_xlabel('Región')
ax5.set_ylabel('Ventas ($)')
ax5.tick_params(axis='x', rotation=45)
ax5.grid(True, alpha=0.3)
for i, v in enumerate(region_ventas):
    ax5.text(i, v, f'${v:,.0f}', ha='center', va='bottom', fontsize=9)

# 6. Variabilidad de Ventas por Categoría (Box Plot)
ax6 = axes[2, 1]
df_supermarket.boxplot(column='ingreso_bruto_diario', by='categoria', ax=ax6, 
                        patch_artist=True, grid=True)
ax6.set_title('Variabilidad de Ventas por Categoría', fontweight='bold')
ax6.set_xlabel('Categoría')
ax6.set_ylabel('Ventas ($)')
ax6.tick_params(axis='x', rotation=45)
plt.suptitle('')  # Remover título automático del boxplot

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Resumen Ejecutivo y Conclusiones

# %%
# PASO 9: Cálculo de métricas clave para el informe ejecutivo
ventas_totales = df_supermarket['ingreso_bruto_diario'].sum()
margen_global = df_supermarket['margen_ganancia_porcentual'].mean()
numero_transacciones = len(df_supermarket)
ticket_promedio = df_supermarket['ingreso_bruto_diario'].mean()

# Identificar categoría líder
categoria_lider = categoria_agg['Ventas Totales ($)'].idxmax()
ventas_categoria_lider = categoria_agg.loc[categoria_lider, 'Ventas Totales ($)']
participacion_categoria_lider = categoria_agg.loc[categoria_lider, 'Participación (%)']

# Identificar región líder
region_lider = region_agg['Ventas Totales ($)'].idxmax()
ventas_region_lider = region_agg.loc[region_lider, 'Ventas Totales ($)']

# Producto estrella
producto_estrella = producto_agg['Ventas Totales ($)'].idxmax()
ventas_producto_estrella = producto_agg.loc[producto_estrella, 'Ventas Totales ($)']
categoria_producto_estrella = producto_agg.loc[producto_estrella, 'Categoría']

print("=" * 80)
print("RESUMEN EJECUTIVO - MÉTRICAS CLAVE DEL NEGOCIO".center(80))
print("=" * 80)
print()
print(f"VENTAS TOTALES 2024:          ${ventas_totales:,.2f}")
print(f"MARGEN PROMEDIO GLOBAL:       {margen_global:.2f}%")
print(f"NÚMERO DE TRANSACCIONES:      {numero_transacciones:,}")
print(f"TICKET PROMEDIO:              ${ticket_promedio:,.2f}")
print()
print("-" * 80)
print("LÍDERES POR DIMENSIÓN")
print("-" * 80)
print(f"Categoría líder:      {categoria_lider}")
print(f"   Ventas:            ${ventas_categoria_lider:,.2f} ({participacion_categoria_lider}% del total)")
print()
print(f"Región líder:         {region_lider}")
print(f"   Ventas:            ${ventas_region_lider:,.2f}")
print()
print(f"Producto estrella:    {producto_estrella} ({categoria_producto_estrella})")
print(f"   Ventas:            ${ventas_producto_estrella:,.2f}")
print()
print(f"Mejor mes:            {meses_nombres[mejor_mes]}")
print(f"   Ventas:            ${ventas_mejor_mes:,.2f}")
print("=" * 80)
# Out:
# ...
#                  RESUMEN EJECUTIVO - MÉTRICAS CLAVE DEL NEGOCIO
# ...
#
# VENTAS TOTALES 2024:          $2,758,461.87
# MARGEN PROMEDIO GLOBAL:       -0.10%
# NÚMERO DE TRANSACCIONES:      1,000
# TICKET PROMEDIO:              $2,758.46
#
# --------------------------------------------------------------------------------
# LÍDERES POR DIMENSIÓN
# --------------------------------------------------------------------------------
# Categoría líder:      Frutas y Verduras
#    Ventas:            $759,059.50 (27.52% del total)
#
# Región líder:         Norte
#    Ventas:            $743,078.62
#
# Producto estrella:    Leche (Panadería)
#    Ventas:            $288,483.52
#
# Mejor mes:            Mayo
#    Ventas:            $311,295.08
# ...

# %% [markdown]
# #### Resumen Ejecutivo
#
# **Período:** 2024 completo (1000 transacciones)
# **Alcance:** 11 productos, 4 categorías, 4 regiones
#
# ---
#
# #### Hallazgos Principales
#
# 1. **Desempeño General**
#    - Las ventas totales alcanzaron $2.76 millones con un ticket promedio de $2,758 por transacción.
#    - Tres categorías concentran cerca del 81% del total: Frutas y Verduras (27.5%), Carnes (27%) y Lácteos (26.3%).
#    - Los márgenes promedio son cercanos a cero o negativos en todas las categorías, lo que requiere revisión de la estructura de costos.
#
# 2. **Distribución Regional**
#    - La región Norte lidera con $743,079 (26.9% del total), mientras que Este presenta el menor desempeño ($576,654).
#    - Existe una brecha del 28.9% entre la región de mayor y menor facturación.
#    - Las diferencias sugieren variaciones en demanda local, competencia o condiciones del mercado.
#
# 3. **Concentración de Productos**
#    - El top 3 de productos (Leche, Pollo, Queso) representa $828,069 (30% de las ventas).
#    - Leche es el producto líder con $288,484, seguido por Pollo ($271,189) y Queso ($268,396).
#    - Los 10 productos principales acumulan aproximadamente el 85% de las ventas totales.
#
# 4. **Estacionalidad**
#    - Mayo registró el pico de ventas ($311,295) mientras que Noviembre presentó el mínimo ($179,665).
#    - La variación entre el mejor y peor mes es del 73%, indicando fuerte estacionalidad.
#    - Esta variabilidad afecta directamente la planificación de inventarios y recursos.
#
# ---
#
# #### Recomendaciones
#
# 1. **Revisar Estructura de Costos**
#    - Analizar por qué los márgenes son negativos o muy bajos en todas las categorías.
#    - Evaluar proveedores, negociar mejores condiciones o ajustar precios de venta.
#    - Priorizar productos con mejor relación precio-costo.
#
# 2. **Fortalecer Regiones de Menor Desempeño**
#    - Identificar las causas del bajo rendimiento en la región Este.
#    - Estudiar las prácticas de la región Norte para replicarlas en otros territorios.
#    - Considerar ajustes en el surtido según preferencias locales.
#
# 3. **Aprovechar la Concentración**
#    - Asegurar disponibilidad constante de los productos top (Leche, Pollo, Queso).
#    - Evaluar si productos de menor rotación aportan valor o pueden descontinuarse.
#    - Implementar promociones cruzadas entre productos complementarios.
#
# 4. **Planificar la Estacionalidad**
#    - Incrementar inventarios antes de mayo y reducirlos hacia noviembre.
#    - Desarrollar promociones específicas para meses de baja actividad.
#    - Ajustar la dotación de personal según los ciclos identificados.
#
# ---
#
# #### Conclusión
#
# El análisis revela un volumen de ventas considerable pero con problemas en la rentabilidad (márgenes negativos). La concentración en pocas categorías y productos reduce riesgos de inventario pero aumenta la dependencia. La fuerte estacionalidad y las diferencias regionales ofrecen oportunidades de mejora mediante planificación más precisa y acciones correctivas en costos y distribución.
